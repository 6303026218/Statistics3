# %%
## Q= Generate a list of 100 integers containing values between 90 to 130 and store it in the variable `int_list`.
## After generating the list, find the following:
##   (i) Write a Python function to calculate the mean of a given list of numbers. Create a function to find the median of a list of numbers.
##   (ii) Develop a program to compute the mode of a list of integers.
##  (iii) Implement a function to calculate the weighted mean of a list of values and their corresponding weights.
##  (iv) Write a Python function to find the geometric mean of a list of positive numbers.
##  (v) Create a program to calculate the harmonic mean of a list of values.
##  (vi) Build a function to determine the midrange of a list of numbers (average of the minimum and maximum).
##  (vii) Implement a Python program to find the trimmed mean of a list, excluding a certain percentage of outliers.

import random

# Generate a list of 100 integers between 90 and 130
int_list = [random.randint(90, 130) for _ in range(100)]

# (i) Mean and Median Functions
def calculate_mean(numbers):
    return sum(numbers) / len(numbers)

def calculate_median(numbers):
    numbers.sort()
    n = len(numbers)
    if n % 2 == 0:
        return (numbers[n//2 - 1] + numbers[n//2]) / 2
    else:
        return numbers[n//2]

# (ii) Mode Function
def calculate_mode(numbers):
    return max(set(numbers), key=numbers.count)

# (iii) Weighted Mean Function
def calculate_weighted_mean(values, weights):
    weighted_sum = sum(value * weight for value, weight in zip(values, weights))
    total_weight = sum(weights)
    return weighted_sum / total_weight

# (iv) Geometric Mean Function
def calculate_geometric_mean(numbers):
    product = 1
    for number in numbers:
        product *= number
    return product ** (1 / len(numbers))

# (v) Harmonic Mean Function
def calculate_harmonic_mean(numbers):
    harmonic_sum = 0
    for number in numbers:
        harmonic_sum += 1 / number
    return len(numbers) / harmonic_sum

# (vi) Midrange Function
def calculate_midrange(numbers):
    return (min(numbers) + max(numbers)) / 2

# (vii) Trimmed Mean Function
def calculate_trimmed_mean(numbers, percentage):
    n = len(numbers)
    k = int(n * percentage / 100)
    sorted_numbers = sorted(numbers)
    trimmed_numbers = sorted_numbers[k:n-k]
    return sum(trimmed_numbers) / len(trimmed_numbers)

# Generate weights for weighted mean (example: random weights)
weights = [random.randint(1, 5) for _ in range(100)]

# Calculate and print the results
mean = calculate_mean(int_list)
median = calculate_median(int_list)
mode = calculate_mode(int_list)
weighted_mean = calculate_weighted_mean(int_list, weights)
geometric_mean = calculate_geometric_mean(int_list)
harmonic_mean = calculate_harmonic_mean(int_list)
midrange = calculate_midrange(int_list)
trimmed_mean = calculate_trimmed_mean(int_list, 10)  # Trim 10% of data

print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
print("Weighted Mean:", weighted_mean)
print("Geometric Mean:", geometric_mean)
print("Harmonic Mean:", harmonic_mean)
print("Midrange:", midrange)
print("Trimmed Mean (10%):", trimmed_mean)
# Out:
# Mean: 109.29
# Median: 109.0
# Mode: 98
# Weighted Mean: 109.43450479233226
# Geometric Mean: 108.7325764825065
# Harmonic Mean: 108.17825161535933
# Midrange: 110.0
# Trimmed Mean (10%): 109.0625

# %%
##  Generate a list of 500 integers containing values between 200 to 300 and store it in the variable `int_list2`.After generating the list, find the following:
##  (i) Compare the given list of visualization for the given data:
##    1. Frequency & Gaussian distribution
##    2. Frequency smoothened KDE plot
##    3. Gaussian distribution & smoothened KDE plot
##  (ii) Write a Python function to calculate the range of a given list of numbers.
##  (iii) Create a program to find the variance and standard deviation of a list of numbers.
##  (iv) Implement a function to compute the interquartile range (IQR) of a list of values.
##  (v) Build a program to calculate the coefficient of variation for a dataset.
##  (vi) Write a Python function to find the mean absolute deviation (MAD) of a list of numbers.
##  (vii) Create a program to calculate the quartile deviation of a list of values.
##  (viii) Implement a function to find the range-based coefficient of dispersion for a dataset.

import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Generate a list of 500 integers between 200 and 300
int_list2 = [random.randint(200, 300) for _ in range(500)]

# (i) Visualizations
plt.figure(figsize=(12, 6))

# 1. Frequency & Gaussian distribution
plt.subplot(1, 3, 1)
plt.hist(int_list2, bins=20, density=True, alpha=0.7, label='Frequency')
x = np.linspace(200, 300, 100)
plt.plot(x, stats.norm.pdf(x, np.mean(int_list2), np.std(int_list2)), label='Gaussian', color='red')
plt.legend()
plt.title('Frequency & Gaussian Distribution')

# 2. Frequency Smoothened KDE Plot
plt.subplot(1, 3, 2)
sns.histplot(int_list2, kde=True, stat='density', bins=20, alpha=0.7)
plt.title('Frequency Smoothened KDE Plot')

# 3. Gaussian Distribution & Smoothened KDE Plot
plt.subplot(1, 3, 3)
sns.kdeplot(int_list2, label='KDE', color='blue')
plt.plot(x, stats.norm.pdf(x, np.mean(int_list2), np.std(int_list2)), label='Gaussian', color='red')
plt.legend()
plt.title('Gaussian Distribution & Smoothened KDE Plot')

plt.tight_layout()
plt.show()

# (ii) Range Function
def calculate_range(numbers):
    return max(numbers) - min(numbers)

# (iii) Variance and Standard Deviation
def calculate_variance_std_dev(numbers):
    variance = np.var(numbers)
    std_dev = np.std(numbers)
    return variance, std_dev

# (iv) Interquartile Range (IQR)
def calculate_iqr(numbers):
    q1 = np.percentile(numbers, 25)
    q3 = np.percentile(numbers, 75)
    return q3 - q1

# (v) Coefficient of Variation
def calculate_coefficient_of_variation(numbers):
    mean = np.mean(numbers)
    std_dev = np.std(numbers)
    return (std_dev / mean) * 100

# (vi) Mean Absolute Deviation (MAD)
def calculate_mad(numbers):
    mean = np.mean(numbers)
    mad = np.mean(np.abs(numbers - mean))
    return mad

# (vii) Quartile Deviation
def calculate_quartile_deviation(numbers):
    q1 = np.percentile(numbers, 25)
    q3 = np.percentile(numbers, 75)
    return (q3 - q1) / 2

# (viii) Range-Based Coefficient of Dispersion
def calculate_range_based_coefficient_of_dispersion(numbers):
    range_val = max(numbers) - min(numbers)
    mean = np.mean(numbers)
    return range_val / mean

# Calculate and print the results
range_value = calculate_range(int_list2)
variance, std_dev = calculate_variance_std_dev(int_list2)
iqr = calculate_iqr(int_list2)
coefficient_of_variation = calculate_coefficient_of_variation(int_list2)
mad = calculate_mad(int_list2)
quartile_deviation = calculate_quartile_deviation(int_list2)
range_based_coefficient_of_dispersion = calculate_range_based_coefficient_of_dispersion(int_list2)

print("Range:", range_value)
print("Variance:", variance)
print("Standard Deviation:", std_dev)
print("Interquartile Range (IQR):", iqr)
print("Coefficient of Variation:", coefficient_of_variation)
print("Mean Absolute Deviation (MAD):", mad)
print("Quartile Deviation:", quartile_deviation)
print("Range-Based Coefficient of Dispersion:", range_based_coefficient_of_dispersion)
# Out:
# Range: 100
# Variance: 859.7154239999999
# Standard Deviation: 29.320904215252295
# Interquartile Range (IQR): 50.0
# Coefficient of Variation: 11.634171434169877
# Mean Absolute Deviation (MAD): 25.148191999999998
# Quartile Deviation: 25.0
# Range-Based Coefficient of Dispersion: 0.39678760752944164

# %%
##  Write a Python class representing a discrete random variable with methods to calculate its expected value and variance.

#
class DiscreteRandomVariable:
    def __init__(self, pmf):
        """
        Initializes a DiscreteRandomVariable object.

        Args:
            pmf (dict): A dictionary representing the probability mass function, where keys are the
                        possible values of the random variable and values are their corresponding probabilities.
        """
        self.pmf = pmf

    def expected_value(self):
        """
        Calculates the expected value (mean) of the random variable.

        Returns:
            float: The expected value.
        """
        expected_value = 0
        for value, probability in self.pmf.items():
            expected_value += value * probability
        return expected_value

    def variance(self):
        """
        Calculates the variance of the random variable.

        Returns:
            float: The variance.
        """
        expected_value = self.expected_value()
        variance = 0
        for value, probability in self.pmf.items():
            variance += probability * (value - expected_value)**2
        return variance

# Example usage:
pmf = {1: 0.2, 2: 0.3, 3: 0.5}
rv = DiscreteRandomVariable(pmf)

print("Expected value:", rv.expected_value())
print("Variance:", rv.variance())
# Out:
# Expected value: 2.3
# Variance: 0.61

# %%
## Implement a program to simulate the rolling of a fair six-sided die and calculate the expected value and variance of the outcomes.


import random

def simulate_die_roll(num_rolls):
    """Simulates rolling a six-sided die a specified number of times.

    Args:
        num_rolls (int): The number of times to roll the die.

    Returns:
        list: A list of the outcomes of each roll.
    """

    rolls = []
    for _ in range(num_rolls):
        roll = random.randint(1, 6)
        rolls.append(roll)
    return rolls

def calculate_expected_value(rolls):
    """Calculates the expected value of a list of rolls.

    Args:
        rolls (list): A list of roll outcomes.

    Returns:
        float: The expected value.
    """

    return sum(rolls) / len(rolls)

def calculate_variance(rolls):
    """Calculates the variance of a list of rolls.

    Args:
        rolls (list): A list of roll outcomes.

    Returns:
        float: The variance.
    """

    mean = sum(rolls) / len(rolls)
    variance = sum((roll - mean) ** 2 for roll in rolls) / len(rolls)
    return variance

# Simulate a large number of rolls
num_rolls = 100000
rolls = simulate_die_roll(num_rolls)

# Calculate the expected value and variance
expected_value = calculate_expected_value(rolls)
variance = calculate_variance(rolls)

print("Expected value:", expected_value)
print("Variance:", variance)
# Out:
# Expected value: 3.50153
# Variance: 2.919317659100002

# %%
## Create a Python function to generate random samples from a given probability distribution (e.g.,binomial, Poisson) and calculate their mean and variance.

#
import numpy as np
import scipy.stats as stats

def generate_samples(distribution, params, sample_size):
  """
  Generates random samples from a given probability distribution.

  Args:
    distribution: The name of the distribution (e.g., 'binomial', 'poisson', 'normal').
    params: A tuple containing the parameters of the distribution.
    sample_size: The number of samples to generate.

  Returns:
    A list of random samples.
  """

  if distribution == 'binomial':
    samples = np.random.binomial(n=params[0], p=params[1], size=sample_size)
  elif distribution == 'poisson':
    samples = np.random.poisson(lam=params[0], size=sample_size)
  elif distribution == 'normal':
    samples = np.random.normal(loc=params[0], scale=params[1], size=sample_size)
  else:
    raise ValueError("Invalid distribution")

  return samples

def calculate_mean_variance(samples):
  """
  Calculates the mean and variance of a list of samples.

  Args:
    samples: A list of samples.

  Returns:
    A tuple containing the mean and variance.
  """

  mean = np.mean(samples)
  variance = np.var(samples)
  return mean, variance

# Example usage:
# Generate 1000 samples from a binomial distribution with n=10, p=0.5
binomial_samples = generate_samples('binomial', (10, 0.5), 1000)
binomial_mean, binomial_variance = calculate_mean_variance(binomial_samples)

# Generate 1000 samples from a Poisson distribution with lambda=5
poisson_samples = generate_samples('poisson', (5,), 1000)
poisson_mean, poisson_variance = calculate_mean_variance(poisson_samples)

print("Binomial distribution:")
print("Mean:", binomial_mean)
print("Variance:", binomial_variance)

print("\nPoisson distribution:")
print("Mean:", poisson_mean)
print("Variance:", poisson_variance)
# Out:
# Binomial distribution:
# Mean: 4.911
# Variance: 2.5070789999999996
#
# Poisson distribution:
# Mean: 5.069
# Variance: 5.016239

# %%
## Write a Python script to generate random numbers from a Gaussian (normal) distribution and compute the mean, variance, and standard deviation of the samples.

# 
import numpy as np

# Generate 1000 random numbers from a normal distribution
# with mean 50 and standard deviation 10
num_samples = 1000
mean = 50
std_dev = 10
samples = np.random.normal(mean, std_dev, num_samples)

# Calculate the mean, variance, and standard deviation
sample_mean = np.mean(samples)
sample_variance = np.var(samples)
sample_std_dev = np.std(samples)

print("Mean:", sample_mean)
print("Variance:", sample_variance)
print("Standard Deviation:", sample_std_dev)
# Out:
# Mean: 50.36634598062048
# Variance: 99.92274888507143
# Standard Deviation: 9.996136697998454

# %%
## Use seaborn library to load tips dataset. Find the following from the dataset for the columns total_bill and tip`:
##  (i) Write a Python function that calculates their skewness.
##  (ii) Create a program that determines whether the columns exhibit positive skewness, negative skewness, or is approximately symmetric.
##  (iii) Write a function that calculates the covariance between two columns.
##  (iv) Implement a Python program that calculates the Pearson correlation coefficient between two columns.
##  (v) Write a script to visualize the correlation between two specific columns in a Pandas DataFrame using scatter plots.

import seaborn as sns
import pandas as pd

# Load the tips dataset
tips = sns.load_dataset("tips")

def calculate_skewness(data):
    """Calculates the skewness of a given dataset.

    Args:
        data: A Pandas Series or NumPy array.

    Returns:
        float: The skewness value.
    """

    return data.skew()

def determine_skewness(skewness):
    """Determines the type of skewness based on the skewness value.

    Args:
        skewness: The skewness value.

    Returns:
        str: A string indicating the type of skewness.
    """

    if skewness > 0:
        return "Positive skewness"
    elif skewness < 0:
        return "Negative skewness"
    else:
        return "Approximately symmetric"

def calculate_covariance(data1, data2):
    """Calculates the covariance between two datasets.

    Args:
        data1: A Pandas Series or NumPy array.
        data2: A Pandas Series or NumPy array.

    Returns:
        float: The covariance value.
    """

    return data1.cov(data2)

def calculate_pearson_correlation(data1, data2):
    """Calculates the Pearson correlation coefficient between two datasets.

    Args:
        data1: A Pandas Series or NumPy array.
        data2: A Pandas Series or NumPy array.

    Returns:
        float: The Pearson correlation coefficient.
    """

    return data1.corr(data2)

def visualize_correlation(data1, data2, xlabel, ylabel, title):
    """Visualizes the correlation between two datasets using a scatter plot.

    Args:
        data1: A Pandas Series or NumPy array.
        data2: A Pandas Series or NumPy array.
        xlabel: The label for the x-axis.
        ylabel: The label for the y-axis.
        title: The title of the plot.
    """

    plt.scatter(data1, data2)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

# Calculate skewness for total_bill and tip
skewness_total_bill = calculate_skewness(tips['total_bill'])
skewness_tip = calculate_skewness(tips['tip'])

print("Skewness of total_bill:", skewness_total_bill)
print("Skewness of tip:", skewness_tip)

# Determine skewness type
print("Skewness type of total_bill:", determine_skewness(skewness_total_bill))
print("Skewness type of tip:", determine_skewness(skewness_tip))

# Calculate covariance
covariance = calculate_covariance(tips['total_bill'], tips['tip'])
print("Covariance between total_bill and tip:", covariance)

# Calculate Pearson correlation coefficient
correlation = calculate_pearson_correlation(tips['total_bill'], tips['tip'])
print("Pearson correlation coefficient between total_bill and tip:", correlation)

# Visualize the correlation
visualize_correlation(tips['total_bill'], tips['tip'], "Total Bill", "Tip", "Total Bill vs. Tip")
# Out:
# Skewness of total_bill: 1.1332130376158205
# Skewness of tip: 1.4654510370979401
# Skewness type of total_bill: Positive skewness
# Skewness type of tip: Positive skewness
# Covariance between total_bill and tip: 8.323501629224854
# Pearson correlation coefficient between total_bill and tip: 0.6757341092113641

# %%
## Write a Python function to calculate the probability density function (PDF) of a continuous random variable for a given normal distribution.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def normal_pdf(x, mean, std_dev):
    """Calculates the probability density function (PDF) of a normal distribution.

    Args:
        x: The value at which to evaluate the PDF.
        mean: The mean of the normal distribution.
        std_dev: The standard deviation of the normal distribution.

    Returns:
        The PDF value at the given x.
    """

    pdf = (1 / (std_dev * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std_dev)**2)
    return pdf

# Example usage:
mean = 0
std_dev = 1
x = np.linspace(-3, 3, 100)
pdf_values = normal_pdf(x, mean, std_dev)

# Plot the PDF
plt.plot(x, pdf_values)
plt.xlabel('x')
plt.ylabel('PDF(x)')
plt.title('Normal Distribution PDF')
plt.grid(True)
plt.show()

# %%
## Create a program to calculate the cumulative distribution function (CDF) of exponential distribution.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import expon

def exponential_cdf(x, rate):
  """Calculates the cumulative distribution function (CDF) of an exponential distribution.

  Args:
    x: The value at which to evaluate the CDF.
    rate: The rate parameter of the exponential distribution.

  Returns:
    The CDF value at the given x.
  """

  return 1 - np.exp(-rate * x)

# Example usage:
rate = 2
x = np.linspace(0, 5, 100)
cdf_values = exponential_cdf(x, rate)

# Plot the CDF
plt.plot(x, cdf_values)
plt.xlabel('x')
plt.ylabel('CDF(x)')
plt.title('Exponential Distribution CDF')
plt.grid(True)
plt.show()

# %%
## Write a Python function to calculate the probability mass function (PMF) of Poisson distribution.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

def poisson_pmf(k, lam):
    """Calculates the probability mass function (PMF) of a Poisson distribution.

    Args:
        k: The number of occurrences.
        lam: The rate parameter of the Poisson distribution.

    Returns:
        The PMF value at the given k.
    """
    pmf = (lam**k * np.exp(-lam)) / np.math.factorial(k)
    return pmf

# Example usage:
lam = 3  # Rate parameter
k_values = np.arange(0, 10)  # k values from 0 to 9
pmf_values = [poisson_pmf(k, lam) for k in k_values]  # Compute PMF for each k

# Plot the PMF
plt.bar(k_values, pmf_values, color='skyblue', alpha=0.7)
plt.xlabel('k')
plt.ylabel('P(X=k)')
plt.title('Poisson Distribution PMF (λ=3)')
plt.xticks(k_values)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
## A company wants to test if a new website layout leads to a higher conversion rate (percentage of visitors
## who make a purchase). They collect data from the old and new layouts to compare.
## To generate the data use the following command:
## import numpy as np
## 50 purchases out of 1000 visitors
## old_layout = np.array([1] * 50 + [0] * 950)
## 70 purchases out of 1000 visitors  
## new_layout = np.array([1] * 70 + [0] * 930)
## Apply z-test to find which layout is successful

import numpy as np
from statsmodels.stats.proportion import proportions_ztest

# Data: Conversion counts and total visitors
old_layout = np.array([1] * 50 + [0] * 950)
new_layout = np.array([1] * 70 + [0] * 930)

# Summarize successes and total samples
successes = [np.sum(old_layout), np.sum(new_layout)]
n_samples = [len(old_layout), len(new_layout)]

# Perform the z-test
z_stat, p_value = proportions_ztest(successes, n_samples, alternative='larger')

# Display results
print(f"Z-Statistic: {z_stat:.4f}")
print(f"P-Value: {p_value:.4f}")

# Conclusion
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The new layout has a significantly higher conversion rate.")
else:
    print("Fail to reject the null hypothesis: No significant evidence that the new layout has a higher conversion rate.")
# Out:
# Z-Statistic: -1.8831
# P-Value: 0.9702
# Fail to reject the null hypothesis: No significant evidence that the new layout has a higher conversion rate.

# %%
## A tutoring service claims that its program improves students' exam scores. A sample of students who participated in the program was taken, and their scores before and after the program were recorded.
## Use the below code to generate samples of respective arrays of marks:
## before_program = np.array([75, 80, 85, 70, 90, 78, 92, 88, 82, 87])
## after_program = np.array([80, 85, 90, 80, 92, 80, 95, 90, 85, 88])
## Use z-test to find if the claims made by tutor are true or false.

import numpy as np
from scipy import stats

# Sample data
before_program = np.array([75, 80, 85, 70, 90, 78, 92, 88, 82, 87])
after_program = np.array([80, 85, 90, 80, 92, 80, 95, 90, 85, 88])

# Perform the paired t-test
t_statistic, p_value = stats.ttest_rel(after_program, before_program)

# Set the significance level (alpha)
alpha = 0.05

# Interpret the results
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the before and after scores.")
    print("The tutoring program appears to be effective.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the before and after scores.")
    print("The tutoring program may not be effective.")
# Out:
# Reject the null hypothesis: There is a significant difference between the before and after scores.
# The tutoring program appears to be effective.

# %%
## A pharmaceutical company wants to determine if a new drug is effective in reducing blood pressure. They conduct a study and record blood pressure measurements before and after administering the drug.
## Use the below code to generate samples of respective arrays of blood pressure:
## before_drug = np.array([145, 150, 140, 135, 155, 160, 152, 148, 130, 138])
## after_drug = np.array([130, 140, 132, 128, 145, 148, 138, 136, 125, 130])
## Implement z-test to find if the drug really works or not.

import numpy as np
from scipy import stats

# Sample data
before_drug = np.array([145, 150, 140, 135, 155, 160, 152, 148, 130, 138])
after_drug = np.array([130, 140, 132, 128, 145, 148, 138, 136, 125, 130])

# Perform the paired t-test
t_statistic, p_value = stats.ttest_rel(before_drug, after_drug)

# Set the significance level (alpha)
alpha = 0.05

# Interpret the results
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference in blood pressure before and after the drug.")
    print("The drug appears to be effective in reducing blood pressure.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference in blood pressure before and after the drug.")
    print("The drug may not be effective in reducing blood pressure.")
# Out:
# Reject the null hypothesis: There is a significant difference in blood pressure before and after the drug.
# The drug appears to be effective in reducing blood pressure.

# %%
## A customer service department claims that their average response time is less than 5 minutes. A sample of recent customer interactions was taken, and the response times were recorded.
## Implement the below code to generate the array of response time:
## response_times = np.array([4.3, 3.8, 5.1, 4.9, 4.7, 4.2, 5.2, 4.5, 4.6, 4.4])
## Implement z-test to find the claims made by customer service department are true or false.

import numpy as np
from scipy.stats import norm

# Sample data
response_times = np.array([4.3, 3.8, 5.1, 4.9, 4.7, 4.2, 5.2, 4.5, 4.6, 4.4])

# Assuming a population standard deviation (σ) of 0.5 minutes (adjust as needed)
sigma = 0.5

# Calculate sample mean and standard error
sample_mean = np.mean(response_times)
standard_error = sigma / np.sqrt(len(response_times))

# Calculate the z-score
z_score = (sample_mean - 5) / standard_error

# Set the significance level (alpha)
alpha = 0.05

# Find the critical z-value
critical_value = norm.ppf(alpha)

# Compare z-score and critical value
if z_score < critical_value:
    print("Reject the null hypothesis. The average response time is significantly less than 5 minutes.")
else:
    print("Fail to reject the null hypothesis. There is not enough evidence to conclude that the average 1  response time is less than 5 minutes.")
# Out:
# Reject the null hypothesis. The average response time is significantly less than 5 minutes.

# %%
## A company is testing two different website layouts to see which one leads to higher click-through rates.
## Write a Python function to perform an A/B test analysis, including calculating the t-statistic, degrees of freedom, and p-value.
## Use the following data:
## layout_a_clicks = [28, 32, 33, 29, 31, 34, 30, 35, 36, 37]
## layout_b_clicks = [40, 41, 38, 42, 39, 44, 43, 41, 45, 47]

import numpy as np
from scipy import stats

def ab_test(group_a, group_b):
  """Performs an A/B test to compare the means of two groups.

  Args:
    group_a: A list of values for group A.
    group_b: A list of values for group B.

  Returns:
    A tuple containing the t-statistic, degrees of freedom, and p-value.
  """

  # Calculate the sample means and standard deviations
  mean_a = np.mean(group_a)
  std_dev_a = np.std(group_a, ddof=1)
  mean_b = np.mean(group_b)
  std_dev_b = np.std(group_b, ddof=1)

  # Calculate the pooled standard deviation
  n1 = len(group_a)
  n2 = len(group_b)
  pooled_std_dev = np.sqrt(((n1 - 1) * std_dev_a**2 + (n2 - 1) * std_dev_b**2) / (n1 + n2 - 2))

  # Calculate the t-statistic
  t_statistic = (mean_a - mean_b) / (pooled_std_dev * np.sqrt(1/n1 + 1/n2))

  # Calculate degrees of freedom
  degrees_of_freedom = n1 + n2 - 2

  # Calculate the p-value
  p_value = stats.t.sf(abs(t_statistic), df=degrees_of_freedom) * 2

  return t_statistic, degrees_of_freedom, p_value

# Sample data
layout_a_clicks = [28, 32, 33, 29, 31, 34, 30, 35, 36, 37]
layout_b_clicks = [40, 41, 38, 42, 39, 44, 43, 41, 45, 47]

# Perform the A/B test
t_stat, df, p_value = ab_test(layout_a_clicks, layout_b_clicks)

print("t-statistic:", t_stat)
print("Degrees of freedom:", df)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. Layout B has a significantly higher click-through rate.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference between the two layouts.")
# Out:
# t-statistic: -7.298102156175071
# Degrees of freedom: 18
# p-value: 8.833437608301987e-07
# Reject the null hypothesis. Layout B has a significantly higher click-through rate.

# %%
## A pharmaceutical company wants to determine if a new drug is more effective than an existing drug in reducing cholesterol levels. Create a program to analyze the clinical trial data and calculate the tstatistic and p-value for the treatment effect.
## Use the following data of cholestrol level:
## existing_drug_levels = [180, 182, 175, 185, 178, 176, 172, 184, 179, 183]
## new_drug_levels = [170, 172, 165, 168, 175, 173, 170, 178, 172, 176]

import numpy as np
import scipy.stats as stats

# Sample data
existing_drug_levels = [180, 182, 175, 185, 178, 176, 172, 184, 179, 183]
new_drug_levels = [170, 172, 165, 168, 175, 173, 170, 178, 172, 176]

# Perform the independent t-test
t_statistic, p_value = stats.ttest_ind(existing_drug_levels, new_drug_levels)

# Set the significance level (alpha)
alpha = 0.05

# Interpret the results
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference in cholesterol levels between the two drugs.")
    print("The new drug appears to be more effective in reducing cholesterol levels.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference in cholesterol levels between the two drugs.")
    print("The new drug may not be more effective than the existing drug.")
# Out:
# Reject the null hypothesis: There is a significant difference in cholesterol levels between the two drugs.
# The new drug appears to be more effective in reducing cholesterol levels.

# %%
## A school district introduces an educational intervention program to improve math scores.
## Write a Python function to analyze pre- and post-intervention test scores, calculating the t-statistic and p-value to determine if the intervention had a significant impact.
## Use the following data of test score:
##  pre_intervention_scores = [80, 85, 90, 75, 88, 82, 92, 78, 85, 87]
##  post_intervention_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]

import numpy as np
from scipy import stats

def analyze_intervention(pre_scores, post_scores):
  """Analyzes the impact of an intervention on test scores using a paired t-test.

  Args:
    pre_scores: A list of pre-intervention test scores.
    post_scores: A list of post-intervention test scores.

  Returns:
    A tuple containing the t-statistic and p-value.
  """

  # Perform the paired t-test
  t_statistic, p_value = stats.ttest_rel(post_scores, pre_scores)

  return t_statistic, p_value

# Sample data
pre_intervention_scores = [80, 85, 90, 75, 88, 82, 92, 78, 85, 87]
post_intervention_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]

# Perform the analysis
t_stat, p_value = analyze_intervention(pre_intervention_scores, post_intervention_scores)

# Set the significance level (alpha)
alpha = 0.05

# Interpret the results
if p_value < alpha:
    print("Reject the null hypothesis: The intervention had a significant impact on test scores.")
else:
    print("Fail to reject the null hypothesis: There is no significant evidence that the intervention improved test scores.")
# Out:
# Reject the null hypothesis: The intervention had a significant impact on test scores.

# %%
## An HR department wants to investigate if there's a gender-based salary gap within the company.
## Develop a program to analyze salary data, calculate the t-statistic, and determine if there's a statistically significant difference between the average salaries of male and female employees.
## Use the below code to generate synthetic data:
# Generate synthetic salary data for male and female employees
## np.random.seed(0)  # For reproducibility
## male_salaries = np.random.normal(loc=50000, scale=10000, size=20)
## female_salaries = np.random.normal(loc=55000, scale=9000, size=20)


import numpy as np
from scipy.stats import ttest_ind

# Generate synthetic salary data
np.random.seed(0)
male_salaries = np.random.normal(loc=50000, scale=10000, size=20)
female_salaries = np.random.normal(loc=55000, scale=9000, size=20)

# Perform independent t-test
t_stat, p_value = ttest_ind(male_salaries, female_salaries)

# Set significance level
alpha = 0.05

# Interpret results
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference in salaries between genders.")
    print("The average salary for females is significantly higher than for males.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference in salaries between genders.")
# Out:
# Fail to reject the null hypothesis: There is no significant difference in salaries between genders.

# %%
## A manufacturer produces two different versions of a product and wants to compare their quality scores.
## Create a Python function to analyze quality assessment data, calculate the t-statistic, and decide whether there's a significant difference in quality between the two versions.
## Use the following data:
## version1_scores = [85, 88, 82, 89, 87, 84, 90, 88, 85, 86, 91, 83, 87, 84, 89, 86, 84, 88, 85, 86, 89, 90, 87, 88, 85]
## version2_scores = [80, 78, 83, 81, 79, 82, 76, 80, 78, 81, 77, 82, 80, 79, 82, 79, 80, 81, 79, 82, 79, 78, 80, 81, 82]

import numpy as np
from scipy.stats import ttest_ind

def analyze_quality(version1_scores, version2_scores, alpha=0.05):
    """
    Analyze quality assessment data using a two-sample t-test.

    Args:
        version1_scores: List of scores for version 1.
        version2_scores: List of scores for version 2.
        alpha: Significance level (default: 0.05).

    Returns:
        t_stat: t-statistic value.
        p_value: p-value of the test.
        conclusion: Decision on whether to reject the null hypothesis.
    """
    # Perform a two-sample t-test
    t_stat, p_value = ttest_ind(version1_scores, version2_scores, equal_var=False)

    # Decide based on p-value
    if p_value < alpha:
        conclusion = "Reject the null hypothesis: There is a significant difference in quality scores."
    else:
        conclusion = "Fail to reject the null hypothesis: No significant difference in quality scores."

    return t_stat, p_value, conclusion


# Data
version1_scores = [85, 88, 82, 89, 87, 84, 90, 88, 85, 86, 91, 83, 87, 84, 89, 86, 84, 88, 85, 86, 89, 90, 87, 88, 85]
version2_scores = [80, 78, 83, 81, 79, 82, 76, 80, 78, 81, 77, 82, 80, 79, 82, 79, 80, 81, 79, 82, 79, 78, 80, 81, 82]

# Analyze the quality scores
t_stat, p_value, conclusion = analyze_quality(version1_scores, version2_scores)

# Display the results
print(f"T-Statistic: {t_stat:.4f}")
print(f"P-Value: {p_value:.4f}")
print(conclusion)
# Out:
# T-Statistic: 11.3258
# P-Value: 0.0000
# Reject the null hypothesis: There is a significant difference in quality scores.

# %%
## A restaurant chain collects customer satisfaction scores for two different branches.
## Write a program to analyze the scores, calculate the t-statistic, and determine if there's a statistically significant difference in customer satisfaction between the branches.
## Use the below data of scores:
## branch_a_scores = [4, 5, 3, 4, 5, 4, 5, 3, 4, 4, 5, 4, 4, 3, 4, 5, 5, 4, 3, 4, 5, 4, 3, 5, 4, 4, 5, 3, 4, 5, 4]
## branch_b_scores = [3, 4, 2, 3, 4, 3, 4, 2, 3, 3, 4, 3, 3, 2, 3, 4, 4, 3, 2, 3, 4, 3, 2, 4, 3, 3, 4, 2, 3, 4, 3]

import numpy as np
from scipy.stats import ttest_ind

def analyze_satisfaction(branch_a_scores, branch_b_scores, alpha=0.05):
    """
    Analyze customer satisfaction scores using a two-sample t-test.

    Args:
        branch_a_scores: List of scores for branch A.
        branch_b_scores: List of scores for branch B.
        alpha: Significance level (default: 0.05).

    Returns:
        t_stat: t-statistic value.
        p_value: p-value of the test.
        conclusion: Decision on whether to reject the null hypothesis.
    """
    # Perform a two-sample t-test
    t_stat, p_value = ttest_ind(branch_a_scores, branch_b_scores, equal_var=False)

    # Decision
    if p_value < alpha:
        conclusion = "Reject the null hypothesis: There is a significant difference in satisfaction scores."
    else:
        conclusion = "Fail to reject the null hypothesis: No significant difference in satisfaction scores."

    return t_stat, p_value, conclusion


# Data
branch_a_scores = [4, 5, 3, 4, 5, 4, 5, 3, 4, 4, 5, 4, 4, 3, 4, 5, 5, 4, 3, 4, 5, 4, 3, 5, 4, 4, 5, 3, 4, 5, 4]
branch_b_scores = [3, 4, 2, 3, 4, 3, 4, 2, 3, 3, 4, 3, 3, 2, 3, 4, 4, 3, 2, 3, 4, 3, 2, 4, 3, 3, 4, 2, 3, 4, 3]

# Analyze the satisfaction scores
t_stat, p_value, conclusion = analyze_satisfaction(branch_a_scores, branch_b_scores)

# Display the results
print(f"T-Statistic: {t_stat:.4f}")
print(f"P-Value: {p_value:.4f}")
print(conclusion)
# Out:
# T-Statistic: 5.4801
# P-Value: 0.0000
# Reject the null hypothesis: There is a significant difference in satisfaction scores.

# %%
## A political analyst wants to determine if there is a significant association between age groups and voter preferences (Candidate A or Candidate B). They collect data from a sample of 500 voters and classify them into different age groups and candidate preferences. Perform a Chi-Square test to determine if there is a significant association between age groups and voter preferences.
## Use the below code to generate data:
## np.random.seed(0)
## age_groups = np.random.choice([ 18 30 , 31 50 , 51+', 51+'], size=30)
## voter_preferences = np.random.choice(['Candidate A', 'Candidate B'], size=30)

import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Generate data
np.random.seed(0)
age_groups = np.random.choice(['18-30', '31-50', '51+'], size=500)
voter_preferences = np.random.choice(['Candidate A', 'Candidate B'], size=500)

# Create a contingency table
data = pd.DataFrame({'Age Group': age_groups, 'Preference': voter_preferences})
contingency_table = pd.crosstab(data['Age Group'], data['Preference'])

# Perform Chi-Square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Display the results
print("Contingency Table:")
print(contingency_table)
print("\nChi-Square Test Results:")
print(f"Chi-Square Statistic: {chi2:.4f}")
print(f"Degrees of Freedom: {dof}")
print(f"P-Value: {p:.4f}")

# Conclusion
alpha = 0.05
if p < alpha:
    print("Reject the null hypothesis: There is a significant association between age groups and voter preferences.")
else:
    print("Fail to reject the null hypothesis: No significant association between age groups and voter preferences.")
# Out:
# Contingency Table:
# Preference  Candidate A  Candidate B
# Age Group
# 18-30                95           87
# 31-50                87           82
# 51+                  84           65
#
# Chi-Square Test Results:
# Chi-Square Statistic: 0.8780
# Degrees of Freedom: 2
# P-Value: 0.6447
# Fail to reject the null hypothesis: No significant association between age groups and voter preferences.

# %%
##  A company conducted a customer satisfaction survey to determine if there is a significant relationship between product satisfaction levels (Satisfied, Neutral, Dissatisfied) and the region where customers are located (East, West, North, South).
## The survey data is summarized in a contingency table.
## Conduct a ChiSquare test to determine if there is a significant relationship between product satisfaction levels and customer regions.
## Sample data:
## Sample data: Product satisfaction levels (rows) vs. Customer regions (columns)
## data = np.array([[50, 30, 40, 20], [30, 40, 30, 50], [20, 30, 40, 30]])

import numpy as np
from scipy.stats import chi2_contingency

# Sample data: Product satisfaction levels (rows) vs. Customer regions (columns)
data = np.array([
    [50, 30, 40, 20],  # Satisfied
    [30, 40, 30, 50],  # Neutral
    [20, 30, 40, 30]   # Dissatisfied
])

# Perform Chi-Square test
chi2, p, dof, expected = chi2_contingency(data)

# Display the results
print("Observed Data:")
print(data)
print("\nExpected Frequencies:")
print(expected)
print(f"\nChi-Square Statistic: {chi2:.4f}")
print(f"Degrees of Freedom: {dof}")
print(f"P-Value: {p:.4f}")

# Conclusion
alpha = 0.05
if p < alpha:
    print("Reject the null hypothesis: There is a significant relationship between product satisfaction levels and customer regions.")
else:
    print("Fail to reject the null hypothesis: No significant relationship between product satisfaction levels and customer regions.")
# Out:
# Observed Data:
# [[50 30 40 20]
#  [30 40 30 50]
#  [20 30 40 30]]
#
# Expected Frequencies:
# [[34.14634146 34.14634146 37.56097561 34.14634146]
#  [36.58536585 36.58536585 40.24390244 36.58536585]
#  [29.26829268 29.26829268 32.19512195 29.26829268]]
#
# Chi-Square Statistic: 27.7771
# Degrees of Freedom: 6
# P-Value: 0.0001
# Reject the null hypothesis: There is a significant relationship between product satisfaction levels and customer regions.

# %%
## A company implemented an employee training program to improve job performance (Effective, Neutral,Ineffective).
## After the training, they collected data from a sample of employees and classified them based on their job performance before and after the training.
## Perform a Chi-Square test to determine if there is a significant difference between job performance levels before and after the training.
## Sample data:
# Sample data: Job performance levels before (rows) and after (columns) training
## data = np.array([[50, 30, 20], [30, 40, 30], [20, 30, 40]])

import numpy as np
from scipy.stats import chi2_contingency

# Sample data: Job performance levels before (rows) and after (columns) training
data = np.array([
    [50, 30, 20],  # Effective, Neutral, Ineffective (before training)
    [30, 40, 30],  # Effective, Neutral, Ineffective (after training)
    [20, 30, 40]   # Effective, Neutral, Ineffective (after training)
])

# Perform Chi-Square test
chi2, p, dof, expected = chi2_contingency(data)

# Display the results
print("Observed Data:")
print(data)
print("\nExpected Frequencies:")
print(expected)
print(f"\nChi-Square Statistic: {chi2:.4f}")
print(f"Degrees of Freedom: {dof}")
print(f"P-Value: {p:.4f}")

# Conclusion
alpha = 0.05
if p < alpha:
    print("Reject the null hypothesis: There is a significant difference in job performance levels before and after the training.")
else:
    print("Fail to reject the null hypothesis: No significant difference in job performance levels before and after the training.")
# Out:
# Observed Data:
# [[50 30 20]
#  [30 40 30]
#  [20 30 40]]
#
# Expected Frequencies:
# [[34.48275862 34.48275862 31.03448276]
#  [34.48275862 34.48275862 31.03448276]
#  [31.03448276 31.03448276 27.93103448]]
#
# Chi-Square Statistic: 22.1617
# Degrees of Freedom: 4
# P-Value: 0.0002
# Reject the null hypothesis: There is a significant difference in job performance levels before and after the training.

# %%
##  A company produces three different versions of a product: Standard, Premium, and Deluxe.
## The company wants to determine if there is a significant difference in customer satisfaction scores among the three product versions.
## They conducted a survey and collected customer satisfaction scores for each version from a random sample of customers.
## Perform an ANOVA test to determine if there is a significant difference in customer satisfaction scores.
##  Use the following data:
## Sample data: Customer satisfaction scores for each product version
##  standard_scores = [80, 85, 90, 78, 88, 82, 92, 78, 85, 87]
##  premium_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]
##  deluxe_scores = [95, 98, 92, 97, 96, 94, 98, 97, 92, 99]

import numpy as np
from scipy.stats import f_oneway

# Sample data: Customer satisfaction scores for each product version
standard_scores = [80, 85, 90, 78, 88, 82, 92, 78, 85, 87]
premium_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]
deluxe_scores = [95, 98, 92, 97, 96, 94, 98, 97, 92, 99]

# Perform One-Way ANOVA
f_stat, p_value = f_oneway(standard_scores, premium_scores, deluxe_scores)

# Display the results
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Conclusion
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference in customer satisfaction scores among the three product versions.")
else:
    print("Fail to reject the null hypothesis: No significant difference in customer satisfaction scores among the three product versions.")
# Out:
# F-statistic: 27.0356
# P-value: 0.0000
# Reject the null hypothesis: There is a significant difference in customer satisfaction scores among the three product versions.
